# %%
import torch
import transformers
from PIL import Image

print("All imports working!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 import transformers
#       3 from PIL import Image
#
# ModuleNotFoundError: No module named 'torch'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\divya\VLM_Project\VLM-integration-moondream\venv\Scripts\python.exe

# %%
# !pip install torch torchvision torchaudio transformers pillow
# Out:
# Requirement already satisfied: torch in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (2.10.0)
# Requirement already satisfied: torchvision in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (0.25.0)
# Requirement already satisfied: torchaudio in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (2.10.0)
# Requirement already satisfied: transformers in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (5.1.0)
# Requirement already satisfied: pillow in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (10.4.0)
# Requirement already satisfied: filelock in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from torch) (3.21.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: numpy in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from torchvision) (2.4.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from transformers) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from transformers) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from transformers) (0.23.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: typer>=0.23.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from typer-slim->transformers) (0.23.0)
# Requirement already satisfied: anyio in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from typer>=0.23.0->typer-slim->transformers) (8.3.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from typer>=0.23.0->typer-slim->transformers) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from typer>=0.23.0->typer-slim->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from rich>=10.11.0->typer>=0.23.0->typer-slim->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from rich>=10.11.0->typer>=0.23.0->typer-slim->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\divya\vlm_project\vlm-integration-moondream\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.0->typer-slim->transformers) (0.1.2)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
import transformers
from PIL import Image

print("All imports working!")
# Out:
# All imports working!

# %%
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration

# Load model (first time will download ~1GB, be patient)
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# Load your image
image_path = "xyz.jpg"   # change if your filename is different
image = Image.open(image_path).convert("RGB")

# Prepare inputs
inputs = processor(image, return_tensors="pt")

# Generate caption
output = model.generate(**inputs, max_new_tokens=50)

# Decode result
caption = processor.decode(output[0], skip_special_tokens=True)

print("Generated caption:", caption)
# Out:
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie text_decoder.cls.predictions.bias to text_decoder.cls.predictions.decoder.bias, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie text_decoder.bert.embeddings.word_embeddings.weight to text_decoder.cls.predictions.decoder.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# BlipForConditionalGeneration LOAD REPORT from: Salesforce/blip-image-captioning-base
# Key                                       | Status     |  |
# ------------------------------------------+------------+--+-
# text_decoder.bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Generated caption: a view of a street from a window
